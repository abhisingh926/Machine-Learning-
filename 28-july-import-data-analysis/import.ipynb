# %%
import pandas as pd
df =pd.read_csv('import_csv/85_Imp_Jun-21.csv', encoding = "ISO-8859-1")
code = [85414011,85414012]
df = df[df['HS_CODE'].isin(code)]
df.head()
# Out:
# /home/abhishek/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (27,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         CUSH             INDIAN_PORT    BE_NO  IMP_DATE         IEC  \
# 3949  INKKU6  Kanakpura - Jaipur ICD  4158719  1-Jun-21  AAACH4717Q
# 4064  INMUN1              Mundra Sea  4155773  1-Jun-21   390011711
# 4065  INMUN1              Mundra Sea  4156884  1-Jun-21   390011711
# 5326  INTKD6             Tughlakabad  4150911  1-Jun-21   514068850
# 5327  INTKD6             Tughlakabad  4150911  1-Jun-21   514068850
#
#                          IMPORTER_NAME  \
# 3949               HASTI INDIA LIMITED
# 4064  TATA POWER SOLAR SYSTEMS LIMITED
# 4065  TATA POWER SOLAR SYSTEMS LIMITED
# 5326               RHINE SOLAR LIMITED
# 5327               RHINE SOLAR LIMITED
#
#                                          ADDRESS                  CITY  \
# 3949                4, NAVJEEVAN COMPLEX, JAIPUR                JAIPUR
# 4064       PLOT NO.78, ELECTRONIC CITYHOSUR ROAD  BANGALORE, KARNATAKA
# 4065       PLOT NO.78, ELECTRONIC CITYHOSUR ROAD  BANGALORE, KARNATAKA
# 5326  A-75/4, IIND FLOORWAZIRPUR INDUSTRIAL AREA             NEW DELHI
# 5327  A-75/4, IIND FLOORWAZIRPUR INDUSTRIAL AREA             NEW DELHI
#
#                CHA_NO                                           CHA_NAME  ...  \
# 3949  AAJCS4801RCH001               SIDDHI VINAYAK CARGO PRIVATE LIMITED  ...
# 4064  AAACB0466ACH015  BABAJI SHIVRAM CLEARING AND CARRIERS PRIVATE L...  ...
# 4065  AAACB0466ACH015  BABAJI SHIVRAM CLEARING AND CARRIERS PRIVATE L...  ...
# 5326  AAECN2245HCH001          NIMIT CARGO MOVERS INDIA PRIVATE LIMITED   ...
# 5327  AAECN2245HCH001          NIMIT CARGO MOVERS INDIA PRIVATE LIMITED   ...
#
#                                     SUPPLIER_ADDRESS  INVOICE_UNITPRICE_FC  \
# 3949  80 ROBINSON ROAD,NO.20-00, SINGAPORE 068898 SG                132.30
# 4064                                             NaN                 99.00
# 4065                                             NaN                 99.00
# 5326                                             NaN                  0.34
# 5327                                             NaN                  0.36
#
#             TYPE  INVOICE_NO   IEC_PIN       PHONE_NO               EMAIL  \
# 3949  H                  NaN       NaN            NaN                 NaN
# 4064  H                  NaN  560100.0  '080-41194230  murgesp@tatabp.com
# 4065  H                  NaN  560100.0  '080-41194230  murgesp@tatabp.com
# 5326  H                  NaN  110052.0  '011-45092992  shiv@rhinesolar.in
# 5327  H                  NaN  110052.0  '011-45092992  shiv@rhinesolar.in
#
#         CONTACT_PERSON  LANDING_PORT_CODE  LANDING_PORT_NAME
# 3949               NaN                NaN             NULL\r
# 4064  MR. RAMAKRISHNAN                NaN             NULL\r
# 4065  MR. RAMAKRISHNAN                NaN             NULL\r
# 5326       SHIV MITTAL                NaN             NULL\r
# 5327       SHIV MITTAL                NaN             NULL\r
#
# [5 rows x 34 columns]

# %%
df
# Out:
#           CUSH                        INDIAN_PORT    BE_NO   IMP_DATE  \
# 3949    INKKU6             Kanakpura - Jaipur ICD  4158719   1-Jun-21
# 4064    INMUN1                         Mundra Sea  4155773   1-Jun-21
# 4065    INMUN1                         Mundra Sea  4156884   1-Jun-21
# 5326    INTKD6                        Tughlakabad  4150911   1-Jun-21
# 5327    INTKD6                        Tughlakabad  4150911   1-Jun-21
# ...        ...                                ...      ...        ...
# 666742  INNSA1                    Nhava Sheva Sea  4514638  30-Jun-21
# 666743  INNSA1                    Nhava Sheva Sea  4514638  30-Jun-21
# 667056  INNSA1                    Nhava Sheva Sea  4511784  30-Jun-21
# 667504  INNSA1                    Nhava Sheva Sea  4509107  30-Jun-21
# 671340  INFLT6  Falta Special Economic Zone (SEZ)  1001118  30-Jun-21
#
#                IEC                               IMPORTER_NAME  \
# 3949    AAACH4717Q                         HASTI INDIA LIMITED
# 4064     390011711            TATA POWER SOLAR SYSTEMS LIMITED
# 4065     390011711            TATA POWER SOLAR SYSTEMS LIMITED
# 5326     514068850                         RHINE SOLAR LIMITED
# 5327     514068850                         RHINE SOLAR LIMITED
# ...            ...                                         ...
# 666742  3111010457               ENRICH ENERGY PRIVATE LIMITED
# 666743  3111010457               ENRICH ENERGY PRIVATE LIMITED
# 667056   314012141  SEVEN GREENS SOLAR SYSTEMS PRIVATE LIMITED
# 667504   996000402                    PREMIER ENERGIES LIMITED
# 671340   205025056                        VIKRAM SOLAR LIMITED
#
#                                                   ADDRESS  \
# 3949                         4, NAVJEEVAN COMPLEX, JAIPUR
# 4064                PLOT NO.78, ELECTRONIC CITYHOSUR ROAD
# 4065                PLOT NO.78, ELECTRONIC CITYHOSUR ROAD
# 5326           A-75/4, IIND FLOORWAZIRPUR INDUSTRIAL AREA
# 5327           A-75/4, IIND FLOORWAZIRPUR INDUSTRIAL AREA
# ...                                                   ...
# 666742  302, THE ORION, 3RD FLR., KOREGAON, PARK ROAD,...
# 666743  302, THE ORION, 3RD FLR., KOREGAON, PARK ROAD,...
# 667056  179 C 20 MIG COLONY OPP MHADA, OFFICE BANDRA EAST
# 667504  SY NO 54 PART, G.PULLA REDDY SWEETS, KAKAGUDA,...
# 671340                FALTA SEZ, SECTOR- II24 PARAGANAS S
#
#                             CITY           CHA_NO  \
# 3949                      JAIPUR  AAJCS4801RCH001
# 4064        BANGALORE, KARNATAKA  AAACB0466ACH015
# 4065        BANGALORE, KARNATAKA  AAACB0466ACH015
# 5326                   NEW DELHI  AAECN2245HCH001
# 5327                   NEW DELHI  AAECN2245HCH001
# ...                          ...              ...
# 666742             PUNE, MHRSHTR              NaN
# 666743             PUNE, MHRSHTR              NaN
# 667056  MAHARASHTRA, MAHARASHTRA              NaN
# 667504        SECUNDERBD, TELNGN              NaN
# 671340                   KOLKATA              NaN
#
#                                                  CHA_NAME  ...  \
# 3949                 SIDDHI VINAYAK CARGO PRIVATE LIMITED  ...
# 4064    BABAJI SHIVRAM CLEARING AND CARRIERS PRIVATE L...  ...
# 4065    BABAJI SHIVRAM CLEARING AND CARRIERS PRIVATE L...  ...
# 5326            NIMIT CARGO MOVERS INDIA PRIVATE LIMITED   ...
# 5327            NIMIT CARGO MOVERS INDIA PRIVATE LIMITED   ...
# ...                                                   ...  ...
# 666742                                                NaN  ...
# 666743                                                NaN  ...
# 667056                                                NaN  ...
# 667504                                                NaN  ...
# 671340                                                NaN  ...
#
#                                          SUPPLIER_ADDRESS  \
# 3949       80 ROBINSON ROAD,NO.20-00, SINGAPORE 068898 SG
# 4064                                                  NaN
# 4065                                                  NaN
# 5326                                                  NaN
# 5327                                                  NaN
# ...                                                   ...
# 666742     80 ROBINSON ROAD,NO.20-00, SINGAPORE 068898 SG
# 666743     80 ROBINSON ROAD,NO.20-00, SINGAPORE 068898 SG
# 667056  UNIT 1520,15/F, TOWER 2, GRAND CENTURY PLACE 1...
# 667504                                                NaN
# 671340  NO 1 BEIJING ROAD ECONOMICDEVELOPMENT ZONE JIA...
#
#         INVOICE_UNITPRICE_FC        TYPE  INVOICE_NO   IEC_PIN       PHONE_NO  \
# 3949              132.300000  H                  NaN       NaN            NaN
# 4064               99.000000  H                  NaN  560100.0  '080-41194230
# 4065               99.000000  H                  NaN  560100.0  '080-41194230
# 5326                0.340000  H                  NaN  110052.0  '011-45092992
# 5327                0.360000  H                  NaN  110052.0  '011-45092992
# ...                      ...         ...         ...       ...            ...
# 666742            125.895000  H                  NaN  411001.0  '918605002352
# 666743            125.895000  H                  NaN  411001.0  '918605002352
# 667056            108.000000  H                  NaN  400051.0  '919819137727
# 667504              0.570000  H                  NaN  500009.0  '919177001518
# 671340              1.626252  NULL        6000001942  743504.0  '919777451565
#
#                                   EMAIL                        CONTACT_PERSON  \
# 3949                                NaN                                   NaN
# 4064                 murgesp@tatabp.com                      MR. RAMAKRISHNAN
# 4065                 murgesp@tatabp.com                      MR. RAMAKRISHNAN
# 5326                 shiv@rhinesolar.in                           SHIV MITTAL
# 5327                 shiv@rhinesolar.in                           SHIV MITTAL
# ...                                 ...                                   ...
# 666742  sanjay.batheja@enrichenergy.com              CHETAN ZAWAR,VIJAY ZAWAR
# 666743  sanjay.batheja@enrichenergy.com              CHETAN ZAWAR,VIJAY ZAWAR
# 667056        swapnil.padhye@7greens.in                        PRADYOT BORKAR
# 667504    ramanjulu@premierenergies.com  SALUJA SURENDERPAL SINGH,KESAR SINGH
# 671340  sujit.choudhury@vikramsolar.com        JOGINDER PAL DUA,CHUNI LAL DUA
#
#         LANDING_PORT_CODE    LANDING_PORT_NAME
# 3949                  NaN               NULL\r
# 4064                  NaN               NULL\r
# 4065                  NaN               NULL\r
# 5326                  NaN               NULL\r
# 5327                  NaN               NULL\r
# ...                   ...                  ...
# 666742                NaN               NULL\r
# 666743                NaN               NULL\r
# 667056                NaN               NULL\r
# 667504                NaN               NULL\r
# 671340             INCCU4  Kolkata Air Cargo\r
#
# [577 rows x 34 columns]

# %%
wp_range = list(range(300,600,5))
WP = list(range(300,600,5))
WP = list(map(str, WP))
wp1 = pd.concat([df['PRODUCT_DESCRIPTION'].str.extract('(?P<WP>{})'.format("|".join(WP)), expand=True).fillna('0')], axis=1)
df['wp']= wp1
df['IMP_DATE'] = pd.to_datetime(df['IMP_DATE'], format='%d-%b-%y')
df
# Out:
#           CUSH                        INDIAN_PORT    BE_NO   IMP_DATE  \
# 3949    INKKU6             Kanakpura - Jaipur ICD  4158719 2021-06-01
# 4064    INMUN1                         Mundra Sea  4155773 2021-06-01
# 4065    INMUN1                         Mundra Sea  4156884 2021-06-01
# 5326    INTKD6                        Tughlakabad  4150911 2021-06-01
# 5327    INTKD6                        Tughlakabad  4150911 2021-06-01
# ...        ...                                ...      ...        ...
# 666742  INNSA1                    Nhava Sheva Sea  4514638 2021-06-30
# 666743  INNSA1                    Nhava Sheva Sea  4514638 2021-06-30
# 667056  INNSA1                    Nhava Sheva Sea  4511784 2021-06-30
# 667504  INNSA1                    Nhava Sheva Sea  4509107 2021-06-30
# 671340  INFLT6  Falta Special Economic Zone (SEZ)  1001118 2021-06-30
#
#                IEC                               IMPORTER_NAME  \
# 3949    AAACH4717Q                         HASTI INDIA LIMITED
# 4064     390011711            TATA POWER SOLAR SYSTEMS LIMITED
# 4065     390011711            TATA POWER SOLAR SYSTEMS LIMITED
# 5326     514068850                         RHINE SOLAR LIMITED
# 5327     514068850                         RHINE SOLAR LIMITED
# ...            ...                                         ...
# 666742  3111010457               ENRICH ENERGY PRIVATE LIMITED
# 666743  3111010457               ENRICH ENERGY PRIVATE LIMITED
# 667056   314012141  SEVEN GREENS SOLAR SYSTEMS PRIVATE LIMITED
# 667504   996000402                    PREMIER ENERGIES LIMITED
# 671340   205025056                        VIKRAM SOLAR LIMITED
#
#                                                   ADDRESS  \
# 3949                         4, NAVJEEVAN COMPLEX, JAIPUR
# 4064                PLOT NO.78, ELECTRONIC CITYHOSUR ROAD
# 4065                PLOT NO.78, ELECTRONIC CITYHOSUR ROAD
# 5326           A-75/4, IIND FLOORWAZIRPUR INDUSTRIAL AREA
# 5327           A-75/4, IIND FLOORWAZIRPUR INDUSTRIAL AREA
# ...                                                   ...
# 666742  302, THE ORION, 3RD FLR., KOREGAON, PARK ROAD,...
# 666743  302, THE ORION, 3RD FLR., KOREGAON, PARK ROAD,...
# 667056  179 C 20 MIG COLONY OPP MHADA, OFFICE BANDRA EAST
# 667504  SY NO 54 PART, G.PULLA REDDY SWEETS, KAKAGUDA,...
# 671340                FALTA SEZ, SECTOR- II24 PARAGANAS S
#
#                             CITY           CHA_NO  \
# 3949                      JAIPUR  AAJCS4801RCH001
# 4064        BANGALORE, KARNATAKA  AAACB0466ACH015
# 4065        BANGALORE, KARNATAKA  AAACB0466ACH015
# 5326                   NEW DELHI  AAECN2245HCH001
# 5327                   NEW DELHI  AAECN2245HCH001
# ...                          ...              ...
# 666742             PUNE, MHRSHTR              NaN
# 666743             PUNE, MHRSHTR              NaN
# 667056  MAHARASHTRA, MAHARASHTRA              NaN
# 667504        SECUNDERBD, TELNGN              NaN
# 671340                   KOLKATA              NaN
#
#                                                  CHA_NAME  ...  \
# 3949                 SIDDHI VINAYAK CARGO PRIVATE LIMITED  ...
# 4064    BABAJI SHIVRAM CLEARING AND CARRIERS PRIVATE L...  ...
# 4065    BABAJI SHIVRAM CLEARING AND CARRIERS PRIVATE L...  ...
# 5326            NIMIT CARGO MOVERS INDIA PRIVATE LIMITED   ...
# 5327            NIMIT CARGO MOVERS INDIA PRIVATE LIMITED   ...
# ...                                                   ...  ...
# 666742                                                NaN  ...
# 666743                                                NaN  ...
# 667056                                                NaN  ...
# 667504                                                NaN  ...
# 671340                                                NaN  ...
#
#        INVOICE_UNITPRICE_FC        TYPE  INVOICE_NO   IEC_PIN       PHONE_NO  \
# 3949             132.300000  H                  NaN       NaN            NaN
# 4064              99.000000  H                  NaN  560100.0  '080-41194230
# 4065              99.000000  H                  NaN  560100.0  '080-41194230
# 5326               0.340000  H                  NaN  110052.0  '011-45092992
# 5327               0.360000  H                  NaN  110052.0  '011-45092992
# ...                     ...         ...         ...       ...            ...
# 666742           125.895000  H                  NaN  411001.0  '918605002352
# 666743           125.895000  H                  NaN  411001.0  '918605002352
# 667056           108.000000  H                  NaN  400051.0  '919819137727
# 667504             0.570000  H                  NaN  500009.0  '919177001518
# 671340             1.626252  NULL        6000001942  743504.0  '919777451565
#
#                                   EMAIL                        CONTACT_PERSON  \
# 3949                                NaN                                   NaN
# 4064                 murgesp@tatabp.com                      MR. RAMAKRISHNAN
# 4065                 murgesp@tatabp.com                      MR. RAMAKRISHNAN
# 5326                 shiv@rhinesolar.in                           SHIV MITTAL
# 5327                 shiv@rhinesolar.in                           SHIV MITTAL
# ...                                 ...                                   ...
# 666742  sanjay.batheja@enrichenergy.com              CHETAN ZAWAR,VIJAY ZAWAR
# 666743  sanjay.batheja@enrichenergy.com              CHETAN ZAWAR,VIJAY ZAWAR
# 667056        swapnil.padhye@7greens.in                        PRADYOT BORKAR
# 667504    ramanjulu@premierenergies.com  SALUJA SURENDERPAL SINGH,KESAR SINGH
# 671340  sujit.choudhury@vikramsolar.com        JOGINDER PAL DUA,CHUNI LAL DUA
#
#         LANDING_PORT_CODE    LANDING_PORT_NAME   wp
# 3949                  NaN               NULL\r  540
# 4064                  NaN               NULL\r  455
# 4065                  NaN               NULL\r  455
# 5326                  NaN               NULL\r    0
# 5327                  NaN               NULL\r    0
# ...                   ...                  ...  ...
# 666742                NaN               NULL\r  545
# 666743                NaN               NULL\r  545
# 667056                NaN               NULL\r  450
# 667504                NaN               NULL\r    0
# 671340             INCCU4  Kolkata Air Cargo\r    0
#
# [577 rows x 35 columns]

# %%
df['SUPPLIER_NAME'] = df['SUPPLIER_NAME'].str.replace('[^\w\s]','')
df['IMPORTER_NAME'] = df['IMPORTER_NAME'].str.replace('[^\w\s]','')
d1 = pd.read_csv('shipper/shipper_jul.csv')
d1['name'] = d1['name'].str.replace('[^\w\s]','')
d11= pd.Series(d1.id.values,index=d1.name).to_dict()
df['supplier_id'] = df['SUPPLIER_NAME'].map(d11)

# %%
df.PRODUCT_DESCRIPTION
# Out:
# 3949                             SOLAR MODULE TSM-540 DE 19
# 4064             PV PANEL,LR4-72HPH-455M/450M-72 CELL LONGI
# 4065             PV PANEL,LR4-72HPH-455M/450M-72 CELL LONGI
# 5326      SOLAR CELL POLY 5BB A GARDE 18.0-18.6% EFF, 4....
# 5327      SOLAR CELL POLY 5BB A GARDE 18.8-18.9% EFF, 4....
#                                 ...
# 666742    TSM-545DE19 MBB HALF CELL SOLAR PV MODULE MONO...
# 666743    TSM-545DE19 MBB HALF CELL SOLAR PV MODULE MONO...
# 667056    SOLAR MODULES CS3W - MS 450 (BIS REF NO.REGIST...
# 667504          SOLAR CELLS ,5BB 157X157 MM 18.7% AND ABOVE
# 671340           BIFACIAL MONO SOLAR CELL (DTL AS PER INV.)
# Name: PRODUCT_DESCRIPTION, Length: 577, dtype: object

# %%
product = pd.read_csv('product/product_9_july.csv')
product.head()
# Out:
#    id              name  power_rating                  created_at  is_active  \
# 0   1    SPR-P3-415-COM           415  2021-05-26 17:50:36.788502          1
# 1   2       TSM-545DE19           545  2021-06-02 08:47:19.222269          1
# 2   3     JKM400M-72H-V           400  2021-06-02 08:49:11.643988          1
# 3   4  TSM-450DE17M(II)           450  2021-06-02 09:14:44.169680          1
# 4   5    LR4-72HPH-450M           450  2021-06-03 03:48:12.235411          1
#
#    created_by_id  supplier_id  type_id
# 0              1          980        3
# 1              1         1033        3
# 2              1          786        3
# 3              1         1033        3
# 4             25          839        3

# %%
mode_name= product['name']

# %%
wp3 = pd.concat([df['PRODUCT_DESCRIPTION'].str.extract('(?P<mode_name>{})'.format("|".join(mode_name)), expand=True).fillna('0')], axis=1)

# %%
wp3
# Out:
#              mode_name  1  2  3  4  5
# 3949                 0  0  0  0  0  0
# 4064    LR4-72HPH-455M  0  0  0  0  0
# 4065    LR4-72HPH-455M  0  0  0  0  0
# 5326                 0  0  0  0  0  0
# 5327                 0  0  0  0  0  0
# ...                ... .. .. .. .. ..
# 666742     TSM-545DE19  0  0  0  0  0
# 666743     TSM-545DE19  0  0  0  0  0
# 667056               0  0  0  0  0  0
# 667504               0  0  0  0  0  0
# 671340               0  0  0  0  0  0
#
# [577 rows x 6 columns]

# %%
df['mode_name']= wp3['mode_name']

# %%
df.columns
# Out:
# Index(['CUSH', 'INDIAN_PORT', 'BE_NO', 'IMP_DATE', 'IEC', 'IMPORTER_NAME',
#        'ADDRESS', 'CITY', 'CHA_NO', 'CHA_NAME', 'ORIGIN_COUNTRY', 'HS_CODE',
#        'PRODUCT_DESCRIPTION', 'QUANTITY', 'UNIT', 'UNIT_VALUE_INR',
#        'TOTAL_ASSESSABLE_VALUE_INR', 'UNIT_PRICE_USD', 'TOTAL_ASSESS_USD',
#        'TOTAL_DUTY_PAID', 'APPRAISING_GROUP', 'PORT_OF_SHIPMENT',
#        'INVOICE_CURRENCY', 'SUPPLIER_NAME', 'SUPPLIER_ADDRESS',
#        'INVOICE_UNITPRICE_FC', 'TYPE', 'INVOICE_NO', 'IEC_PIN', 'PHONE_NO',
#        'EMAIL', 'CONTACT_PERSON', 'LANDING_PORT_CODE', 'LANDING_PORT_NAME',
#        'wp', 'supplier_id', 'import_product_id'],
#       dtype='object')

# %%
p11= pd.Series(product.id.values,index=product.name).to_dict()
df['import_product_id'] = df['mode_name'].map(d11)
df = df.drop(columns=['mode_name'])

# %%
ok=df[['CUSH', 'INDIAN_PORT', 'BE_NO', 'IMP_DATE', 'IEC', 'IMPORTER_NAME',
       'ADDRESS', 'CITY', 'CHA_NO', 'CHA_NAME', 'ORIGIN_COUNTRY', 'HS_CODE',
       'PRODUCT_DESCRIPTION', 'QUANTITY', 'UNIT', 'UNIT_VALUE_INR',
       'TOTAL_ASSESSABLE_VALUE_INR', 'UNIT_PRICE_USD', 'TOTAL_ASSESS_USD',
       'TOTAL_DUTY_PAID', 'APPRAISING_GROUP', 'PORT_OF_SHIPMENT',
       'INVOICE_CURRENCY', 'SUPPLIER_NAME', 'SUPPLIER_ADDRESS',
       'INVOICE_UNITPRICE_FC', 'TYPE', 'INVOICE_NO', 'IEC_PIN', 'PHONE_NO',
       'EMAIL', 'CONTACT_PERSON', 'LANDING_PORT_CODE', 'LANDING_PORT_NAME']]

# %%
ok1=df[[ 'PRODUCT_DESCRIPTION','wp', 'supplier_id', 'import_product_id']]

# %%
ok1.to_csv("june2.csv" )

# %%
df.to_csv('may_total_2021.csv')

# %%
df =pd.read_csv('latest upload/2021.csv', encoding = "ISO-8859-1")
df1 =pd.read_csv('latest upload/2020.csv', encoding = "ISO-8859-1")
df2 =pd.read_csv('latest upload/2019.csv', encoding = "ISO-8859-1")

# %%
fd = pd.concat([df,df1,df2])
fd.to_csv('total.csv')
