# %% [markdown]
# The corr() method will actually get rid of the columns that are not suitable for correlation for you. if you wanted less categories in the heat map, then we can select only those columns.

# %%
import pandas as pd
import seaborn
import matplotlib.pyplot as plt
from vega_datasets import data

# %%
# !pip3 install vega_datasets
# Out:
# Collecting vega_datasets
#   Downloading vega_datasets-0.9.0-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 3.9 MB/s eta 0:00:01
# Requirement already satisfied: pandas in /home/abhishek/.local/lib/python3.8/site-packages (from vega_datasets) (1.1.3)
# Requirement already satisfied: numpy>=1.15.4 in /home/abhishek/.local/lib/python3.8/site-packages (from pandas->vega_datasets) (1.19.2)
# Requirement already satisfied: pytz>=2017.2 in /home/abhishek/.local/lib/python3.8/site-packages (from pandas->vega_datasets) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/abhishek/.local/lib/python3.8/site-packages (from pandas->vega_datasets) (2.8.1)
# Requirement already satisfied: six>=1.5 in /home/abhishek/.local/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->vega_datasets) (1.15.0)
# Installing collected packages: vega-datasets
# Successfully installed vega-datasets-0.9.0

# %%
cars= data.cars()
cars
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# 0         130.0           3504          12.0 1970-01-01     USA
# 1         165.0           3693          11.5 1970-01-01     USA
# 2         150.0           3436          11.0 1970-01-01     USA
# 3         150.0           3433          12.0 1970-01-01     USA
# 4         140.0           3449          10.5 1970-01-01     USA
# ..          ...            ...           ...        ...     ...
# 401        86.0           2790          15.6 1982-01-01     USA
# 402        52.0           2130          24.6 1982-01-01  Europe
# 403        84.0           2295          11.6 1982-01-01     USA
# 404        79.0           2625          18.6 1982-01-01     USA
# 405        82.0           2720          19.4 1982-01-01     USA
#
# [406 rows x 9 columns]

# %%
cars.head()
# Out:
#                         Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    Horsepower  Weight_in_lbs  Acceleration       Year Origin
# 0       130.0           3504          12.0 1970-01-01    USA
# 1       165.0           3693          11.5 1970-01-01    USA
# 2       150.0           3436          11.0 1970-01-01    USA
# 3       150.0           3433          12.0 1970-01-01    USA
# 4       140.0           3449          10.5 1970-01-01    USA

# %%
cars.columns
# Out:
# Index(['Name', 'Miles_per_Gallon', 'Cylinders', 'Displacement', 'Horsepower',
#        'Weight_in_lbs', 'Acceleration', 'Year', 'Origin'],
#       dtype='object')

# %%
cars = cars[[ 'Miles_per_Gallon', 'Cylinders', 'Displacement', 'Horsepower',
       'Weight_in_lbs', 'Acceleration']]
cars.head()
# Out:
#    Miles_per_Gallon  Cylinders  Displacement  Horsepower  Weight_in_lbs  \
# 0              18.0          8         307.0       130.0           3504
# 1              15.0          8         350.0       165.0           3693
# 2              18.0          8         318.0       150.0           3436
# 3              16.0          8         304.0       150.0           3433
# 4              17.0          8         302.0       140.0           3449
#
#    Acceleration
# 0          12.0
# 1          11.5
# 2          11.0
# 3          12.0
# 4          10.5

# %%
cars.corr()
# Out:
#                   Miles_per_Gallon  Cylinders  Displacement  Horsepower  \
# Miles_per_Gallon          1.000000  -0.775396     -0.804203   -0.778427
# Cylinders                -0.775396   1.000000      0.951787    0.844158
# Displacement             -0.804203   0.951787      1.000000    0.898326
# Horsepower               -0.778427   0.844158      0.898326    1.000000
# Weight_in_lbs            -0.831741   0.895220      0.932475    0.866586
# Acceleration              0.420289  -0.522452     -0.557984   -0.697124
#
#                   Weight_in_lbs  Acceleration
# Miles_per_Gallon      -0.831741      0.420289
# Cylinders              0.895220     -0.522452
# Displacement           0.932475     -0.557984
# Horsepower             0.866586     -0.697124
# Weight_in_lbs          1.000000     -0.430086
# Acceleration          -0.430086      1.000000

# %% [markdown]
#     Signature: cars.corr(method ='pearson',min_periods=1)
#     Docstring:
#     Computer pairwaise correlation of columns, excluding NA/null values.
#
#     Parameters:
#     method : {'pearson', 'kendall', 'spearman'} or callable
#     * pearson : standard orrelations coefficient
#     * kendall : Kendall Tau correlations coefficient
#     * spearman: Spearman rank correlation
#     * callable: callable with input two 1D nd arrays and
#         returning a float
#       .. versiona added :: .024.0

# %% [markdown]
# #
